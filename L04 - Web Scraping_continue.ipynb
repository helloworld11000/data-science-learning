# %% [markdown]
# # L04 - Web Crawling
#
# ** Learning Objectives **
#
# - Your first Python Applications
# - Get your own data
# - Learn automation from your code!

# %% [markdown]
# ![http-1.png](data:image/png;base64,...)

# %% [markdown]
# Credit: https://researchhubs.com

# %%
# Installation Code if BeautifulSoup is missing
#! pip3 install BeautifulSoup

# %%
import requests 
from bs4 import BeautifulSoup

# %% [markdown]
# ### Simple request: Playground

# %% [markdown]
# What is Request?   https://docs.python-requests.org/en/master/
#
# HTTP Status Code  https://en.wikipedia.org/wiki/List_of_HTTP_status_codes

# %%
# send a request to server request.get

# %%
# Example Case of Header is needed
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
requests.get("https://www.openrice.com", headers=headers)
# Out:
# <Response [200]>

# %%
# ! pip install Pillow

# %%
# Load Image Data
from PIL import Image
from io import BytesIO
image_r = requests.get(url = "https://www.price.com.hk/space/product/466000/466385_ycyr9f_4.png")
img = Image.open(BytesIO(image_r.content))

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
#Show the soup

# %% [markdown]
# #### HTML basic
#
# ![carbon (1).png](data:image/png;base64,...)

# %% [markdown]
# #### Meta Tags example

# %%
sample = """
<html lang="zh-HK">
<head>
<meta name="keywords" content="價格,數碼,影音,遊戲,相機,電腦,硬件,電器,手提電話,手機,價目,價目表,價格比較,Price,Uwants,Discuss,格價網,產品格價,價錢,shopping,price list">
<meta name="description" content="Price 為香港No.1格價網站，提供多元化的產品或服務資訊、價格及用家評價等，讓精明的消費者在選購前能有充足的了解，並格至最抵價。產品或服務類型包括手提電話、電腦、家庭電器、玩具、嬰兒用品、手袋皮具、旅行套票、餐飲、美容等。Price 兼有二手買賣功能，讓用戶可以隨時去舊迎新。">
<meta name="ir-site-verification-token" value="1535863020" />
<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
<meta http-equiv="X-UA-Compatible" content="IE=edge">
<\html>
"""

# %% [markdown]
# #### Beautiful Soup .find

# %% [markdown]
# #### Beautiful Soup .findAll

# %% [markdown]
# #### Class exercise 1: Find all meta tags with name only

# %%
# What attrs in the beautifulsoup

# %%
# Your code here

# %% [markdown]
# #### Class exercise 2: Find Name and Price for Dyson Products

# %%
# get how many pages

# for each page, crawl info

# locate product name, price from where

# return the result to list of dictionary

# wrap as a function

# %%
# multiple page:
# 1 page done -> which variable will change page -> loop that variable

# save all names and price into a holder
